# %% [markdown]
# # Analyze code with help of Pure Python

# %%
import csv
import statistics
import time

start = time.time()
from collections import defaultdict, Counter

def load_data(filepath):
    with open(filepath, 'r', encoding='utf-8') as f:
        return list(csv.DictReader(f))

def is_number(s):
    try: float(s); return True
    except: return False

def get_numeric_columns(data):
    return [col for col in data[0] if all(is_number(row[col]) or row[col]=='' for row in data[:100])]

def compute_stats(data, column):
    values = [float(row[column]) for row in data if is_number(row[column])]
    if not values:
        return {
            'count': 0,
            'mean': None,
            'min': None,
            'max': None,
            'std': None
        }
    return {
        'count': len(values),
        'mean': statistics.mean(values),
        'min': min(values),
        'max': max(values),
        'std': statistics.stdev(values) if len(values) > 1 else 0
    }


def compute_categorical_stats(data, column):
    values = [row[column] for row in data if row[column]]
    freq = Counter(values)
    return {
        'count': len(values),
        'unique': len(set(values)),
        'most_common': freq.most_common(1)[0] if freq else None
    }

def group_by(data, keys):
    grouped = defaultdict(list)
    for row in data:
        # ✅ Check all keys exist in the row before accessing
        if all(k in row for k in keys):
            key = tuple(row[k] for k in keys)
            grouped[key].append(row)
    return grouped

# %%
name = "Facebook Ads"
path = "Downloads/period_03/2024_fb_ads_president_scored_anon.csv"

print(f"\n\n📊 === Analyzing {name} ===")
data = load_data(path)
numeric_cols = get_numeric_columns(data)

print("\n=== Overall Stats ===")
for col in data[0]:
    print(f"\n{col}:")
    if col in numeric_cols:
        print(compute_stats(data, col))
    else:
        print(compute_categorical_stats(data, col))

print("\n=== Grouped by page_id ===")
for key, rows in list(group_by(data, ['page_id']).items())[:3]:
    print(f"\nGroup: {key}")
    for col in numeric_cols:
        print(f"  {col}:", compute_stats(rows, col))

if "ad_id" in data[0]:
    print("\n=== Grouped by page_id and ad_id ===")
    for key, rows in list(group_by(data, ['page_id', 'ad_id']).items())[:3]:
        print(f"\nGroup: {key}")
        for col in numeric_cols:
            print(f"  {col}:", compute_stats(rows, col))
# Out:
# 📊 === Analyzing Facebook Ads ===
#
# === Overall Stats ===
#
# page_id:
# {'count': 246745, 'unique': 4475, 'most_common': ('4d66f5853f0365dba032a87704a634f023d15babde973bb7a284ed8cd2707b2d', 55503)}
#
# ad_id:
# {'count': 246745, 'unique': 246745, 'most_common': ('0ddb025b8544e2d58e6977ad417e742a52522b3e1fc1c9d9b61c57148f8d72fc', 1)}
#
# ad_creation_time:
# {'count': 246745, 'unique': 547, 'most_common': ('2024-10-27', 8619)}
#
# bylines:
# {'count': 245736, 'unique': 3790, 'most_common': ('HARRIS FOR PRESIDENT', 49788)}
#
# currency:
# {'count': 246745, 'unique': 18, 'most_common': ('USD', 246599)}
#
# delivery_by_region:
# {'count': 246745, 'unique': 141122, 'most_common': ('{}', 30989)}
#
# demographic_distribution:
# {'count': 246745, 'unique': 215622, 'most_common': ('{}', 30989)}
#
# estimated_audience_size:
# {'count': 246745, 'mean': 556462.8559687126, 'min': 0.0, 'max': 1000001.0, 'std': 409864.75882290734}
#
# estimated_impressions:
# {'count': 246745, 'mean': 45601.52595189366, 'min': 499.0, 'max': 1000000.0, 'std': 136790.76990104263}
#
# estimated_spend:
# {'count': 246745, 'mean': 1061.2914344768892, 'min': 49.0, 'max': 474999.0, 'std': 4992.560748793634}
#
# publisher_platforms:
# {'count': 246745, 'unique': 9, 'most_common': ("['facebook', 'instagram']", 214434)}
#
# illuminating_scored_message:
# {'count': 246745, 'unique': 26338, 'most_common': ('e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855', 5972)}
#
# illuminating_mentions:
# {'count': 246745, 'unique': 278, 'most_common': ('[]', 73205)}
#
# scam_illuminating:
# {'count': 246745, 'mean': 0.07163265719670105, 'min': 0.0, 'max': 1.0, 'std': 0.25787921423700266}
#
# election_integrity_Truth_illuminating:
# {'count': 246745, 'mean': 0.05008814768283045, 'min': 0.0, 'max': 1.0, 'std': 0.21812729763428282}
#
# advocacy_msg_type_illuminating:
# {'count': 246745, 'mean': 0.5486311779367363, 'min': 0.0, 'max': 1.0, 'std': 0.49763039712576856}
#
# issue_msg_type_illuminating:
# {'count': 246745, 'mean': 0.38164907090315914, 'min': 0.0, 'max': 1.0, 'std': 0.485792151038562}
#
# attack_msg_type_illuminating:
# {'count': 246745, 'mean': 0.27185555938316885, 'min': 0.0, 'max': 1.0, 'std': 0.44491675228584093}
#
# image_msg_type_illuminating:
# {'count': 246745, 'mean': 0.22270360088350322, 'min': 0.0, 'max': 1.0, 'std': 0.4160617845957763}
#
# cta_msg_type_illuminating:
# {'count': 246745, 'mean': 0.5727694583476869, 'min': 0.0, 'max': 1.0, 'std': 0.49467726617114893}
#
# engagement_cta_subtype_illuminating:
# {'count': 246745, 'mean': 0.12486980485926767, 'min': 0.0, 'max': 1.0, 'std': 0.33057189773339457}
#
# fundraising_cta_subtype_illuminating:
# {'count': 246745, 'mean': 0.22848689943058623, 'min': 0.0, 'max': 1.0, 'std': 0.4198587270099655}
#
# voting_cta_subtype_illuminating:
# {'count': 246745, 'mean': 0.1438448600782184, 'min': 0.0, 'max': 1.0, 'std': 0.35093306401909335}
#
# covid_topic_illuminating:
# {'count': 246745, 'mean': 0.024875884009807697, 'min': 0.0, 'max': 1.0, 'std': 0.15574714351540456}
#
# economy_topic_illuminating:
# {'count': 246745, 'mean': 0.12212202881517356, 'min': 0.0, 'max': 1.0, 'std': 0.3274273558898461}
#
# education_topic_illuminating:
# {'count': 246745, 'mean': 0.01432653143934021, 'min': 0.0, 'max': 1.0, 'std': 0.11883324100080564}
#
# environment_topic_illuminating:
# {'count': 246745, 'mean': 0.02124865752092241, 'min': 0.0, 'max': 1.0, 'std': 0.14421246950536118}
#
# foreign_policy_topic_illuminating:
# {'count': 246745, 'mean': 0.005264544367667025, 'min': 0.0, 'max': 1.0, 'std': 0.07236608434896528}
#
# governance_topic_illuminating:
# {'count': 246745, 'mean': 0.025641856977851627, 'min': 0.0, 'max': 1.0, 'std': 0.15806471271206604}
#
# health_topic_illuminating:
# {'count': 246745, 'mean': 0.10918964923301384, 'min': 0.0, 'max': 1.0, 'std': 0.3118776425724781}
#
# immigration_topic_illuminating:
# {'count': 246745, 'mean': 0.03356906928205232, 'min': 0.0, 'max': 1.0, 'std': 0.1801175126153678}
#
# lgbtq_issues_topic_illuminating:
# {'count': 246745, 'mean': 0.0032300553202699142, 'min': 0.0, 'max': 1.0, 'std': 0.05674182858640465}
#
# military_topic_illuminating:
# {'count': 246745, 'mean': 0.002176335893331172, 'min': 0.0, 'max': 1.0, 'std': 0.04660051777000881}
#
# race_and_ethnicity_topic_illuminating:
# {'count': 246745, 'mean': 0.01243388923787716, 'min': 0.0, 'max': 1.0, 'std': 0.11081217172130096}
#
# safety_topic_illuminating:
# {'count': 246745, 'mean': 0.03372307442906645, 'min': 0.0, 'max': 1.0, 'std': 0.18051581854071772}
#
# social_and_cultural_topic_illuminating:
# {'count': 246745, 'mean': 0.10583801090194331, 'min': 0.0, 'max': 1.0, 'std': 0.3076308012712654}
#
# technology_and_privacy_topic_illuminating:
# {'count': 246745, 'mean': 0.0011550386026059293, 'min': 0.0, 'max': 1.0, 'std': 0.03396629453070909}
#
# womens_issue_topic_illuminating:
# {'count': 246745, 'mean': 0.08090944092078867, 'min': 0.0, 'max': 1.0, 'std': 0.27269654319083053}
#
# incivility_illuminating:
# {'count': 246745, 'mean': 0.18752558309185596, 'min': 0.0, 'max': 1.0, 'std': 0.3903336473569034}
#
# freefair_illuminating:
# {'count': 246745, 'mean': 0.006415530203246266, 'min': 0.0, 'max': 1.0, 'std': 0.07983982095047255}
#
# fraud_illuminating:
# {'count': 246745, 'mean': 0.0026383513343735433, 'min': 0.0, 'max': 1.0, 'std': 0.05129718414363082}
#
# === Grouped by page_id ===
#
# Group: ('4ff23a48b53d988df50ddfebb0e442a984ab8f94e874ef9b9cb34394e0c5d230',)
#   estimated_audience_size: {'count': 33, 'mean': 43636.36363636364, 'min': 30000.0, 'max': 75000.0, 'std': 21001.21749717469}
#   estimated_impressions: {'count': 33, 'mean': 66908.09090909091, 'min': 499.0, 'max': 374999.0, 'std': 96605.54902422907}
#   estimated_spend: {'count': 33, 'mean': 467.1818181818182, 'min': 49.0, 'max': 2249.0, 'std': 663.067938381197}
#   scam_illuminating: {'count': 33, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0.0}
#   election_integrity_Truth_illuminating: {'count': 33, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0.0}
#   advocacy_msg_type_illuminating: {'count': 33, 'mean': 1.0, 'min': 1.0, 'max': 1.0, 'std': 0.0}
#   issue_msg_type_illuminating: {'count': 33, 'mean': 1.0, 'min': 1.0, 'max': 1.0, 'std': 0.0}
#   attack_msg_type_illuminating: {'count': 33, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0.0}
#   image_msg_type_illuminating: {'count': 33, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0.0}
#   cta_msg_type_illuminating: {'count': 33, 'mean': 0.42424242424242425, 'min': 0.0, 'max': 1.0, 'std': 0.5018903659106632}
#   engagement_cta_subtype_illuminating: {'count': 33, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0.0}
#   fundraising_cta_subtype_illuminating: {'count': 33, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0.0}
#   voting_cta_subtype_illuminating: {'count': 33, 'mean': 0.42424242424242425, 'min': 0.0, 'max': 1.0, 'std': 0.5018903659106632}
#   covid_topic_illuminating: {'count': 33, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0.0}
#   economy_topic_illuminating: {'count': 33, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0.0}
#   education_topic_illuminating: {'count': 33, 'mean': 0.42424242424242425, 'min': 0.0, 'max': 1.0, 'std': 0.5018903659106632}
#   environment_topic_illuminating: {'count': 33, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0.0}
#   foreign_policy_topic_illuminating: {'count': 33, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0.0}
#   governance_topic_illuminating: {'count': 33, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0.0}
#   health_topic_illuminating: {'count': 33, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0.0}
#   immigration_topic_illuminating: {'count': 33, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0.0}
#   lgbtq_issues_topic_illuminating: {'count': 33, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0.0}
#   military_topic_illuminating: {'count': 33, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0.0}
#   race_and_ethnicity_topic_illuminating: {'count': 33, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0.0}
#   safety_topic_illuminating: {'count': 33, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0.0}
#   social_and_cultural_topic_illuminating: {'count': 33, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0.0}
#   technology_and_privacy_topic_illuminating: {'count': 33, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0.0}
#   womens_issue_topic_illuminating: {'count': 33, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0.0}
#   incivility_illuminating: {'count': 33, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0.0}
#   freefair_illuminating: {'count': 33, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0.0}
#   fraud_illuminating: {'count': 33, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0.0}
#
# Group: ('b9eb7e353e596d5fc99568d4ef77d4b11ced3243537cbd0895dde3195b69b6be',)
#   estimated_audience_size: {'count': 3, 'mean': 1000001.0, 'min': 1000001.0, 'max': 1000001.0, 'std': 0.0}
#   estimated_impressions: {'count': 3, 'mean': 16165.666666666666, 'min': 499.0, 'max': 47499.0, 'std': 27135.46265191241}
#   estimated_spend: {'count': 3, 'mean': 82.33333333333333, 'min': 49.0, 'max': 149.0, 'std': 57.735026918962575}
#   scam_illuminating: {'count': 3, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0.0}
#   election_integrity_Truth_illuminating: {'count': 3, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0.0}
#   advocacy_msg_type_illuminating: {'count': 3, 'mean': 0.3333333333333333, 'min': 0.0, 'max': 1.0, 'std': 0.5773502691896257}
#   issue_msg_type_illuminating: {'count': 3, 'mean': 0.6666666666666666, 'min': 0.0, 'max': 1.0, 'std': 0.5773502691896257}
#   attack_msg_type_illuminating: {'count': 3, 'mean': 0.6666666666666666, 'min': 0.0, 'max': 1.0, 'std': 0.5773502691896257}
#   image_msg_type_illuminating: {'count': 3, 'mean': 0.3333333333333333, 'min': 0.0, 'max': 1.0, 'std': 0.5773502691896257}
#   cta_msg_type_illuminating: {'count': 3, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0.0}
#   engagement_cta_subtype_illuminating: {'count': 3, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0.0}
#   fundraising_cta_subtype_illuminating: {'count': 3, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0.0}
#   voting_cta_subtype_illuminating: {'count': 3, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0.0}
#   covid_topic_illuminating: {'count': 3, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0.0}
#   economy_topic_illuminating: {'count': 3, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0.0}
#   education_topic_illuminating: {'count': 3, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0.0}
#   environment_topic_illuminating: {'count': 3, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0.0}
#   foreign_policy_topic_illuminating: {'count': 3, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0.0}
#   governance_topic_illuminating: {'count': 3, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0.0}
#   health_topic_illuminating: {'count': 3, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0.0}
#   immigration_topic_illuminating: {'count': 3, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0.0}
#   lgbtq_issues_topic_illuminating: {'count': 3, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0.0}
#   military_topic_illuminating: {'count': 3, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0.0}
#   race_and_ethnicity_topic_illuminating: {'count': 3, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0.0}
#   safety_topic_illuminating: {'count': 3, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0.0}
#   social_and_cultural_topic_illuminating: {'count': 3, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0.0}
#   technology_and_privacy_topic_illuminating: {'count': 3, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0.0}
#   womens_issue_topic_illuminating: {'count': 3, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0.0}
#   incivility_illuminating: {'count': 3, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0.0}
#   freefair_illuminating: {'count': 3, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0.0}
#   fraud_illuminating: {'count': 3, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0.0}
#
# Group: ('7167146d80bba9d877a246d9682c7eecf3cae7b63337cf8ec01fff2eff27c909',)
#   estimated_audience_size: {'count': 7, 'mean': 1000001.0, 'min': 1000001.0, 'max': 1000001.0, 'std': 0.0}
#   estimated_impressions: {'count': 7, 'mean': 641.8571428571429, 'min': 499.0, 'max': 1499.0, 'std': 377.9644730092272}
#   estimated_spend: {'count': 7, 'mean': 49.0, 'min': 49.0, 'max': 49.0, 'std': 0.0}
#   scam_illuminating: {'count': 7, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0.0}
#   election_integrity_Truth_illuminating: {'count': 7, 'mean': 0.14285714285714285, 'min': 0.0, 'max': 1.0, 'std': 0.37796447300922725}
#   advocacy_msg_type_illuminating: {'count': 7, 'mean': 0.2857142857142857, 'min': 0.0, 'max': 1.0, 'std': 0.4879500364742666}
#   issue_msg_type_illuminating: {'count': 7, 'mean': 0.2857142857142857, 'min': 0.0, 'max': 1.0, 'std': 0.4879500364742666}
#   attack_msg_type_illuminating: {'count': 7, 'mean': 0.42857142857142855, 'min': 0.0, 'max': 1.0, 'std': 0.5345224838248488}
#   image_msg_type_illuminating: {'count': 7, 'mean': 0.42857142857142855, 'min': 0.0, 'max': 1.0, 'std': 0.5345224838248488}
#   cta_msg_type_illuminating: {'count': 7, 'mean': 0.14285714285714285, 'min': 0.0, 'max': 1.0, 'std': 0.37796447300922725}
#   engagement_cta_subtype_illuminating: {'count': 7, 'mean': 0.14285714285714285, 'min': 0.0, 'max': 1.0, 'std': 0.37796447300922725}
#   fundraising_cta_subtype_illuminating: {'count': 7, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0.0}
#   voting_cta_subtype_illuminating: {'count': 7, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0.0}
#   covid_topic_illuminating: {'count': 7, 'mean': 0.14285714285714285, 'min': 0.0, 'max': 1.0, 'std': 0.37796447300922725}
#   economy_topic_illuminating: {'count': 7, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0.0}
#   education_topic_illuminating: {'count': 7, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0.0}
#   environment_topic_illuminating: {'count': 7, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0.0}
#   foreign_policy_topic_illuminating: {'count': 7, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0.0}
#   governance_topic_illuminating: {'count': 7, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0.0}
#   health_topic_illuminating: {'count': 7, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0.0}
#   immigration_topic_illuminating: {'count': 7, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0.0}
#   lgbtq_issues_topic_illuminating: {'count': 7, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0.0}
#   military_topic_illuminating: {'count': 7, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0.0}
#   race_and_ethnicity_topic_illuminating: {'count': 7, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0.0}
#   safety_topic_illuminating: {'count': 7, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0.0}
#   social_and_cultural_topic_illuminating: {'count': 7, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0.0}
#   technology_and_privacy_topic_illuminating: {'count': 7, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0.0}
#   womens_issue_topic_illuminating: {'count': 7, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0.0}
#   incivility_illuminating: {'count': 7, 'mean': 0.14285714285714285, 'min': 0.0, 'max': 1.0, 'std': 0.37796447300922725}
#   freefair_illuminating: {'count': 7, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0.0}
#   fraud_illuminating: {'count': 7, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0.0}
#
# === Grouped by page_id and ad_id ===
#
# Group: ('4ff23a48b53d988df50ddfebb0e442a984ab8f94e874ef9b9cb34394e0c5d230', '0ddb025b8544e2d58e6977ad417e742a52522b3e1fc1c9d9b61c57148f8d72fc')
#   estimated_audience_size: {'count': 1, 'mean': 30000.0, 'min': 30000.0, 'max': 30000.0, 'std': 0}
#   estimated_impressions: {'count': 1, 'mean': 47499.0, 'min': 47499.0, 'max': 47499.0, 'std': 0}
#   estimated_spend: {'count': 1, 'mean': 249.0, 'min': 249.0, 'max': 249.0, 'std': 0}
#   scam_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0}
#   election_integrity_Truth_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0}
#   advocacy_msg_type_illuminating: {'count': 1, 'mean': 1.0, 'min': 1.0, 'max': 1.0, 'std': 0}
#   issue_msg_type_illuminating: {'count': 1, 'mean': 1.0, 'min': 1.0, 'max': 1.0, 'std': 0}
#   attack_msg_type_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0}
#   image_msg_type_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0}
#   cta_msg_type_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0}
#   engagement_cta_subtype_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0}
#   fundraising_cta_subtype_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0}
#   voting_cta_subtype_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0}
#   covid_topic_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0}
#   economy_topic_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0}
#   education_topic_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0}
#   environment_topic_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0}
#   foreign_policy_topic_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0}
#   governance_topic_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0}
#   health_topic_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0}
#   immigration_topic_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0}
#   lgbtq_issues_topic_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0}
#   military_topic_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0}
#   race_and_ethnicity_topic_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0}
#   safety_topic_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0}
#   social_and_cultural_topic_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0}
#   technology_and_privacy_topic_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0}
#   womens_issue_topic_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0}
#   incivility_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0}
#   freefair_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0}
#   fraud_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0}
#
# Group: ('4ff23a48b53d988df50ddfebb0e442a984ab8f94e874ef9b9cb34394e0c5d230', '86229868e6bde3661724fe02da93504bb4fb5da8c2550d7b7cf193c687e89fa6')
#   estimated_audience_size: {'count': 1, 'mean': 75000.0, 'min': 75000.0, 'max': 75000.0, 'std': 0}
#   estimated_impressions: {'count': 1, 'mean': 22499.0, 'min': 22499.0, 'max': 22499.0, 'std': 0}
#   estimated_spend: {'count': 1, 'mean': 49.0, 'min': 49.0, 'max': 49.0, 'std': 0}
#   scam_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0}
#   election_integrity_Truth_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0}
#   advocacy_msg_type_illuminating: {'count': 1, 'mean': 1.0, 'min': 1.0, 'max': 1.0, 'std': 0}
#   issue_msg_type_illuminating: {'count': 1, 'mean': 1.0, 'min': 1.0, 'max': 1.0, 'std': 0}
#   attack_msg_type_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0}
#   image_msg_type_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0}
#   cta_msg_type_illuminating: {'count': 1, 'mean': 1.0, 'min': 1.0, 'max': 1.0, 'std': 0}
#   engagement_cta_subtype_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0}
#   fundraising_cta_subtype_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0}
#   voting_cta_subtype_illuminating: {'count': 1, 'mean': 1.0, 'min': 1.0, 'max': 1.0, 'std': 0}
#   covid_topic_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0}
#   economy_topic_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0}
#   education_topic_illuminating: {'count': 1, 'mean': 1.0, 'min': 1.0, 'max': 1.0, 'std': 0}
#   environment_topic_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0}
#   foreign_policy_topic_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0}
#   governance_topic_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0}
#   health_topic_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0}
#   immigration_topic_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0}
#   lgbtq_issues_topic_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0}
#   military_topic_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0}
#   race_and_ethnicity_topic_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0}
#   safety_topic_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0}
#   social_and_cultural_topic_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0}
#   technology_and_privacy_topic_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0}
#   womens_issue_topic_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0}
#   incivility_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0}
#   freefair_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0}
#   fraud_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0}
#
# Group: ('4ff23a48b53d988df50ddfebb0e442a984ab8f94e874ef9b9cb34394e0c5d230', '07b5aefc27e872e971f793e49aac38496fa62e484f3928e2b6a2b6e3e08cac8d')
#   estimated_audience_size: {'count': 1, 'mean': 75000.0, 'min': 75000.0, 'max': 75000.0, 'std': 0}
#   estimated_impressions: {'count': 1, 'mean': 32499.0, 'min': 32499.0, 'max': 32499.0, 'std': 0}
#   estimated_spend: {'count': 1, 'mean': 149.0, 'min': 149.0, 'max': 149.0, 'std': 0}
#   scam_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0}
#   election_integrity_Truth_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0}
#   advocacy_msg_type_illuminating: {'count': 1, 'mean': 1.0, 'min': 1.0, 'max': 1.0, 'std': 0}
#   issue_msg_type_illuminating: {'count': 1, 'mean': 1.0, 'min': 1.0, 'max': 1.0, 'std': 0}
#   attack_msg_type_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0}
#   image_msg_type_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0}
#   cta_msg_type_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0}
#   engagement_cta_subtype_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0}
#   fundraising_cta_subtype_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0}
#   voting_cta_subtype_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0}
#   covid_topic_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0}
#   economy_topic_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0}
#   education_topic_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0}
#   environment_topic_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0}
#   foreign_policy_topic_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0}
#   governance_topic_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0}
#   health_topic_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0}
#   immigration_topic_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0}
#   lgbtq_issues_topic_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0}
#   military_topic_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0}
#   race_and_ethnicity_topic_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0}
#   safety_topic_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0}
#   social_and_cultural_topic_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0}
#   technology_and_privacy_topic_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0}
#   womens_issue_topic_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0}
#   incivility_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0}
#   freefair_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0}
#   fraud_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0}

# %%
name = "Facebook Posts"
path = "Downloads/period_03/2024_fb_posts_president_scored_anon.csv"

print(f"\n\n📊 === Analyzing {name} ===")
data = load_data(path)
numeric_cols = get_numeric_columns(data)

print("\n=== Overall Stats ===")
for col in data[0]:
    print(f"\n{col}:")
    if col in numeric_cols:
        print(compute_stats(data, col))
    else:
        print(compute_categorical_stats(data, col))

print("\n=== Grouped by page_id ===")
groups = list(group_by(data, ['page_id']).items())
print(f"📌 Total groups: {len(groups)}")

for key, rows in groups[:3]:
    print(f"\nGroup: {key}")
    for col in numeric_cols:
        print(f"  {col}:", compute_stats(rows, col))


if "ad_id" in data[0]:
    print("\n=== Grouped by page_id and ad_id ===")
    for key, rows in list(group_by(data, ['page_id', 'ad_id']).items())[:3]:
        print(f"\nGroup: {key}")
        for col in numeric_cols:
            print(f"  {col}:", compute_stats(rows, col))
# Out:
# 📊 === Analyzing Facebook Posts ===
#
# === Overall Stats ===
#
# Facebook_Id:
# {'count': 19009, 'unique': 21, 'most_common': ('32fc18da91029ff09bf74fe9887eace6b5d2145809d583f696e344530508b064', 9013)}
#
# post_id:
# {'count': 19009, 'unique': 19009, 'most_common': ('8570b69695e00d8f06b12398ed525497e1712b5369c6fc2138fe98f69811c138', 1)}
#
# Page Category:
# {'count': 16537, 'unique': 6, 'most_common': ('PERSON', 9453)}
#
# Page Admin Top Country:
# {'count': 16280, 'unique': 1, 'most_common': ('US', 16280)}
#
# Post Created:
# {'count': 19009, 'unique': 18951, 'most_common': ('2023-11-14 11:11:44 EST', 2)}
#
# Post Created Date:
# {'count': 19009, 'unique': 425, 'most_common': ('2024-10-31', 103)}
#
# Post Created Time:
# {'count': 19009, 'unique': 16102, 'most_common': ('19:42:00', 7)}
#
# Type:
# {'count': 16544, 'unique': 9, 'most_common': ('Link', 7404)}
#
# Total Interactions:
# {'count': 19009, 'unique': 5665, 'most_common': ('23', 115)}
#
# Likes:
# {'count': 19009, 'mean': 2377.6954074385817, 'min': 0.0, 'max': 351979.0, 'std': 11253.469668562246}
#
# Comments:
# {'count': 19009, 'mean': 901.583197432795, 'min': 0.0, 'max': 93872.0, 'std': 3681.980096241411}
#
# Shares:
# {'count': 19009, 'mean': 320.53895523173236, 'min': 0.0, 'max': 76150.0, 'std': 1722.1598787908092}
#
# Love:
# {'count': 19009, 'mean': 413.87732126887266, 'min': 0.0, 'max': 244482.0, 'std': 3730.9404497835785}
#
# Wow:
# {'count': 19009, 'mean': 5.8683255300120996, 'min': 0.0, 'max': 4345.0, 'std': 52.946978621835086}
#
# Haha:
# {'count': 19009, 'mean': 105.71971171550318, 'min': 0.0, 'max': 99276.0, 'std': 942.034248188069}
#
# Sad:
# {'count': 19009, 'mean': 10.172181598190331, 'min': 0.0, 'max': 56111.0, 'std': 418.3250070508284}
#
# Angry:
# {'count': 19009, 'mean': 20.05550002630333, 'min': 0.0, 'max': 11814.0, 'std': 156.020088838535}
#
# Care:
# {'count': 19009, 'mean': 34.92903361565574, 'min': 0.0, 'max': 85236.0, 'std': 790.1032133297068}
#
# Video Share Status:
# {'count': 3271, 'unique': 3, 'most_common': ('owned', 3100)}
#
# Is Video Owner?:
# {'count': 16544, 'unique': 3, 'most_common': ('-', 13280)}
#
# Post Views:
# {'count': 16544, 'mean': 6485.058510638298, 'min': 0.0, 'max': 4276477.0, 'std': 90392.95844483374}
#
# Total Views:
# {'count': 16544, 'mean': 7461.847014023211, 'min': 0.0, 'max': 4462155.0, 'std': 95976.27884773155}
#
# Total Views For All Crossposts:
# {'count': 16544, 'mean': 3555.9379835589943, 'min': 0.0, 'max': 4499458.0, 'std': 88094.04831888726}
#
# Video Length:
# {'count': 3271, 'unique': 774, 'most_common': ('00:00:30', 83)}
#
# Sponsor Id:
# {'count': 0, 'mean': None, 'min': None, 'max': None, 'std': None}
#
# Sponsor Name:
# {'count': 0, 'mean': None, 'min': None, 'max': None, 'std': None}
#
# Sponsor Category:
# {'count': 0, 'mean': None, 'min': None, 'max': None, 'std': None}
#
# Overperforming Score:
# {'count': 16544, 'mean': -2.744160420696325, 'min': -198.75, 'max': 246.78, 'std': 7.808476956626709}
#
# illuminating_scored_messageelection_integrity_Truth_illuminating:
# {'count': 0, 'mean': None, 'min': None, 'max': None, 'std': None}
#
# advocacy_msg_type_illuminating:
# {'count': 19009, 'mean': 0.549266137092956, 'min': 0.0, 'max': 1.0, 'std': 0.497580016079574}
#
# issue_msg_type_illuminating:
# {'count': 19009, 'mean': 0.4603082750276185, 'min': 0.0, 'max': 1.0, 'std': 0.498435187805786}
#
# attack_msg_type_illuminating:
# {'count': 19009, 'mean': 0.2166868325530012, 'min': 0.0, 'max': 1.0, 'std': 0.4119982751678418}
#
# image_msg_type_illuminating:
# {'count': 19009, 'mean': 0.14856120784891366, 'min': 0.0, 'max': 1.0, 'std': 0.35566477191124185}
#
# cta_msg_type_illuminating:
# {'count': 19009, 'mean': 0.1328318165079699, 'min': 0.0, 'max': 1.0, 'std': 0.3394018046223717}
#
# engagement_cta_subtype_illuminating:
# {'count': 19009, 'mean': 0.0908517018254511, 'min': 0.0, 'max': 1.0, 'std': 0.28740566368291404}
#
# fundraising_cta_subtype_illuminating:
# {'count': 19009, 'mean': 0.01841233100110474, 'min': 0.0, 'max': 1.0, 'std': 0.13444057384240987}
#
# voting_cta_subtype_illuminating:
# {'count': 19009, 'mean': 0.023409963701404597, 'min': 0.0, 'max': 1.0, 'std': 0.15120562176830252}
#
# covid_topic_illuminating:
# {'count': 19009, 'mean': 0.05239623336314377, 'min': 0.0, 'max': 1.0, 'std': 0.22283060875079394}
#
# economy_topic_illuminating:
# {'count': 19009, 'mean': 0.09037824188542269, 'min': 0.0, 'max': 1.0, 'std': 0.2867304314176825}
#
# education_topic_illuminating:
# {'count': 19009, 'mean': 0.014992898100899574, 'min': 0.0, 'max': 1.0, 'std': 0.12152731400515626}
#
# environment_topic_illuminating:
# {'count': 19009, 'mean': 0.022252617181335158, 'min': 0.0, 'max': 1.0, 'std': 0.14750790777543615}
#
# foreign_policy_topic_illuminating:
# {'count': 19009, 'mean': 0.03687726866221264, 'min': 0.0, 'max': 1.0, 'std': 0.18846539275137483}
#
# governance_topic_illuminating:
# {'count': 19009, 'mean': 0.03109053606186543, 'min': 0.0, 'max': 1.0, 'std': 0.17356698831044248}
#
# health_topic_illuminating:
# {'count': 19009, 'mean': 0.04866116050291967, 'min': 0.0, 'max': 1.0, 'std': 0.2151643265574399}
#
# immigration_topic_illuminating:
# {'count': 19009, 'mean': 0.04082276816244937, 'min': 0.0, 'max': 1.0, 'std': 0.19788463748089133}
#
# lgbtq_issues_topic_illuminating:
# {'count': 19009, 'mean': 0.0033668262402020096, 'min': 0.0, 'max': 1.0, 'std': 0.057928121424024204}
#
# military_topic_illuminating:
# {'count': 19009, 'mean': 0.0055763059603345785, 'min': 0.0, 'max': 1.0, 'std': 0.07446813078449072}
#
# race_and_ethnicity_topic_illuminating:
# {'count': 19009, 'mean': 0.021568730601294123, 'min': 0.0, 'max': 1.0, 'std': 0.1452743291351743}
#
# safety_topic_illuminating:
# {'count': 19009, 'mean': 0.032195275921931714, 'min': 0.0, 'max': 1.0, 'std': 0.17652302788510535}
#
# social_and_cultural_topic_illuminating:
# {'count': 19009, 'mean': 0.06170761218370246, 'min': 0.0, 'max': 1.0, 'std': 0.24063006640218323}
#
# technology_and_privacy_topic_illuminating:
# {'count': 19009, 'mean': 0.0020516597401230995, 'min': 0.0, 'max': 1.0, 'std': 0.04524995190747905}
#
# womens_issue_topic_illuminating:
# {'count': 19009, 'mean': 0.0254616234415277, 'min': 0.0, 'max': 1.0, 'std': 0.15752661549177788}
#
# incivility_illuminating:
# {'count': 19009, 'mean': 0.1278867904676732, 'min': 0.0, 'max': 1.0, 'std': 0.3339724942470072}
#
# scam_illuminating:
# {'count': 18060, 'mean': 0.020210409745293468, 'min': 0.0, 'max': 1.0, 'std': 0.1407232944376072}
#
# freefair_illuminating:
# {'count': 19009, 'mean': 0.0028407596401704457, 'min': 0.0, 'max': 1.0, 'std': 0.05322441874762225}
#
# fraud_illuminating:
# {'count': 19009, 'mean': 0.00862749224051765, 'min': 0.0, 'max': 1.0, 'std': 0.09248518037867293}
#
# === Grouped by page_id ===
# 📌 Total groups: 0

# %%
name = "Twitter Posts"
path = "Downloads/period_03/2024_tw_posts_president_scored_anon.csv"

print(f"\n\n📊 === Analyzing {name} ===")
data = load_data(path)
numeric_cols = get_numeric_columns(data)

print("\n=== Overall Stats ===")
for col in data[0]:
    print(f"\n{col}:")
    if col in numeric_cols:
        print(compute_stats(data, col))
    else:
        print(compute_categorical_stats(data, col))

print("\n=== Grouped by page_id ===")
for key, rows in list(group_by(data, ['page_id']).items())[:3]:
    print(f"\nGroup: {key}")
    for col in numeric_cols:
        print(f"  {col}:", compute_stats(rows, col))

if "ad_id" in data[0]:
    print("\n=== Grouped by page_id and ad_id ===")
    for key, rows in list(group_by(data, ['page_id', 'ad_id']).items())[:3]:
        print(f"\nGroup: {key}")
        for col in numeric_cols:
            print(f"  {col}:", compute_stats(rows, col))

end = time.time()
print(f"⏱️ Time taken: {end - start:.2f} seconds")
# Out:
# 📊 === Analyzing Twitter Posts ===
#
# === Overall Stats ===
#
# id:
# {'count': 27304, 'unique': 27304, 'most_common': ('cc46051622b8a9c1b883a3bbf12c640b12ac1cbdc7f48a773b6cc2a65f03aa2d', 1)}
#
# url:
# {'count': 27304, 'unique': 27304, 'most_common': ('f70a206472e9deaf6e313297c1efb891729ced346a0aeb34e16935d78f74b937', 1)}
#
# source:
# {'count': 27304, 'unique': 14, 'most_common': ('Twitter Web App', 14930)}
#
# retweetCount:
# {'count': 27304, 'mean': 1322.0551933782597, 'min': 0.0, 'max': 144615.0, 'std': 3405.0042401645187}
#
# replyCount:
# {'count': 27304, 'mean': 1063.7850131848813, 'min': 0.0, 'max': 121270.0, 'std': 3174.981654139348}
#
# likeCount:
# {'count': 27304, 'mean': 6913.69282888954, 'min': 0.0, 'max': 915221.0, 'std': 21590.307989209447}
#
# quoteCount:
# {'count': 27304, 'mean': 128.08156314093173, 'min': 0.0, 'max': 123320.0, 'std': 1131.5334680019284}
#
# viewCount:
# {'count': 27304, 'mean': 507084.7318341635, 'min': 5.0, 'max': 333502775.0, 'std': 3212173.9862966556}
#
# createdAt:
# {'count': 27304, 'unique': 27014, 'most_common': ('2023-10-06 04:55:21', 4)}
#
# lang:
# {'count': 27304, 'unique': 12, 'most_common': ('en', 27281)}
#
# bookmarkCount:
# {'count': 27304, 'mean': 136.21352182830356, 'min': 0.0, 'max': 42693.0, 'std': 712.5802944831519}
#
# isReply:
# {'count': 27304, 'unique': 2, 'most_common': ('False', 23930)}
#
# isRetweet:
# {'count': 27304, 'unique': 1, 'most_common': ('False', 27304)}
#
# isQuote:
# {'count': 27304, 'unique': 2, 'most_common': ('False', 24064)}
#
# isConversationControlled:
# {'count': 27304, 'unique': 2, 'most_common': ('False', 27296)}
#
# quoteId:
# {'count': 3287, 'mean': 1.7642983966589504e+18, 'min': 7.912639390153769e+17, 'max': 1.8535761683325583e+18, 'std': 6.894686649329474e+16}
#
# inReplyToId:
# {'count': 3345, 'mean': 1.7582857247419999e+18, 'min': 1.2400673584227e+18, 'max': 1.853530653414859e+18, 'std': 4.36119657015607e+16}
#
# month_year:
# {'count': 27304, 'unique': 15, 'most_common': ('2024-10', 3586)}
#
# illuminating_scored_message:
# {'count': 27304, 'unique': 27136, 'most_common': ('36cb7d55fcf85362ca03f624c2f574f1f55f89db559b17da084df6e643afe5cd', 21)}
#
# election_integrity_Truth_illuminating:
# {'count': 26034, 'mean': 0.03714373511561804, 'min': 0.0, 'max': 1.0, 'std': 0.1891175609378361}
#
# advocacy_msg_type_illuminating:
# {'count': 26034, 'mean': 0.5636859491434278, 'min': 0.0, 'max': 1.0, 'std': 0.4959370396322804}
#
# issue_msg_type_illuminating:
# {'count': 26034, 'mean': 0.507682261657832, 'min': 0.0, 'max': 1.0, 'std': 0.4999505813425477}
#
# attack_msg_type_illuminating:
# {'count': 26034, 'mean': 0.3075977567795959, 'min': 0.0, 'max': 1.0, 'std': 0.46150791760416376}
#
# image_msg_type_illuminating:
# {'count': 26034, 'mean': 0.22643466236460014, 'min': 0.0, 'max': 1.0, 'std': 0.41853164098392054}
#
# cta_msg_type_illuminating:
# {'count': 26034, 'mean': 0.10966428516555274, 'min': 0.0, 'max': 1.0, 'std': 0.31247684757947275}
#
# engagement_cta_subtype_illuminating:
# {'count': 26034, 'mean': 0.0669124990397173, 'min': 0.0, 'max': 1.0, 'std': 0.24987519849406606}
#
# fundraising_cta_subtype_illuminating:
# {'count': 26034, 'mean': 0.007874318199277867, 'min': 0.0, 'max': 1.0, 'std': 0.08838898916084756}
#
# voting_cta_subtype_illuminating:
# {'count': 26034, 'mean': 0.016785741722363065, 'min': 0.0, 'max': 1.0, 'std': 0.1284702866854094}
#
# covid_topic_illuminating:
# {'count': 26034, 'mean': 0.0076054390412537455, 'min': 0.0, 'max': 1.0, 'std': 0.08687857194055204}
#
# economy_topic_illuminating:
# {'count': 26034, 'mean': 0.16021356687408772, 'min': 0.0, 'max': 1.0, 'std': 0.3668110523395825}
#
# education_topic_illuminating:
# {'count': 26034, 'mean': 0.01843742797879696, 'min': 0.0, 'max': 1.0, 'std': 0.13452949268938846}
#
# environment_topic_illuminating:
# {'count': 26034, 'mean': 0.028539602058846123, 'min': 0.0, 'max': 1.0, 'std': 0.16651173583618067}
#
# foreign_policy_topic_illuminating:
# {'count': 26034, 'mean': 0.042252439118076364, 'min': 0.0, 'max': 1.0, 'std': 0.20116839951473553}
#
# governance_topic_illuminating:
# {'count': 26034, 'mean': 0.022969962356917877, 'min': 0.0, 'max': 1.0, 'std': 0.1498105645777889}
#
# health_topic_illuminating:
# {'count': 26034, 'mean': 0.05565798571099332, 'min': 0.0, 'max': 1.0, 'std': 0.2292644615290389}
#
# immigration_topic_illuminating:
# {'count': 26034, 'mean': 0.06529922409157256, 'min': 0.0, 'max': 1.0, 'std': 0.2470578473918854}
#
# lgbtq_issues_topic_illuminating:
# {'count': 26034, 'mean': 0.0030729046631328264, 'min': 0.0, 'max': 1.0, 'std': 0.05534961243011968}
#
# military_topic_illuminating:
# {'count': 26034, 'mean': 0.010985634170699855, 'min': 0.0, 'max': 1.0, 'std': 0.10423707289416256}
#
# race_and_ethnicity_topic_illuminating:
# {'count': 26034, 'mean': 0.015402934623953292, 'min': 0.0, 'max': 1.0, 'std': 0.12315139782021392}
#
# safety_topic_illuminating:
# {'count': 26034, 'mean': 0.03760467081508796, 'min': 0.0, 'max': 1.0, 'std': 0.19024181908327997}
#
# social_and_cultural_topic_illuminating:
# {'count': 26034, 'mean': 0.05197050011523392, 'min': 0.0, 'max': 1.0, 'std': 0.22197175454151633}
#
# technology_and_privacy_topic_illuminating:
# {'count': 26034, 'mean': 0.0020357993393254974, 'min': 0.0, 'max': 1.0, 'std': 0.04507474794044172}
#
# womens_issue_topic_illuminating:
# {'count': 26034, 'mean': 0.02331566413152032, 'min': 0.0, 'max': 1.0, 'std': 0.15090698683369944}
#
# incivility_illuminating:
# {'count': 26034, 'mean': 0.17857417223630637, 'min': 0.0, 'max': 1.0, 'std': 0.3830027047455516}
#
# scam_illuminating:
# {'count': 26034, 'mean': 0.012368441269109626, 'min': 0.0, 'max': 1.0, 'std': 0.11052570813895939}
#
# freefair_illuminating:
# {'count': 27304, 'mean': 0.0014283621447406974, 'min': 0.0, 'max': 1.0, 'std': 0.037767369074478356}
#
# fraud_illuminating:
# {'count': 27304, 'mean': 0.0027468502783474947, 'min': 0.0, 'max': 1.0, 'std': 0.05233932958795364}
#
# === Grouped by page_id ===
# ⏱️ Time taken: 17.81 seconds

# %% [markdown]
# ### 📌 Note:
# We couldn't perform a **group by `page_id`** operation on the other two datasets because the `page_id` column was not present in those files.
# As a result, the grouped data for `page_id` is blank for those datasets.

# %%
import csv
import math
from collections import defaultdict, Counter
import time

start = time.time()

file_path = "Downloads/period_03/trump_truths_dataset.csv"

# Load data
with open(file_path, newline='', encoding='utf-8') as f:
    reader = csv.DictReader(f)
    data = list(reader)

# Determine numeric fields
sample = data[0]
numeric_cols = []
for key in sample:
    try:
        float(sample[key])
        numeric_cols.append(key)
    except:
        continue

# Stats container
stats = defaultdict(lambda: {"count": 0, "sum": 0.0, "min": float('inf'), "max": float('-inf'), "values": []})

# Loop over rows
for row in data:
    for key, val in row.items():
        if val == '':
            continue
        stats[key]["count"] += 1
        if key in numeric_cols:
            try:
                num = float(val)
                stats[key]["sum"] += num
                stats[key]["min"] = min(stats[key]["min"], num)
                stats[key]["max"] = max(stats[key]["max"], num)
                stats[key]["values"].append(num)
            except:
                pass
        else:
            stats[key]["values"].append(val)

# Compute and print results
for key, s in stats.items():
    print(f"\n📊 Column: {key}")
    print(f" - Count: {s['count']}")
    if key in numeric_cols:
        mean = s['sum'] / s['count'] if s['count'] else 0
        std_dev = math.sqrt(sum((x - mean) ** 2 for x in s['values']) / s['count']) if s['count'] else 0
        print(f" - Mean: {mean:.2f}")
        print(f" - Min: {s['min']}")
        print(f" - Max: {s['max']}")
        print(f" - Std Dev: {std_dev:.2f}")
    else:
        counter = Counter(s["values"])
        most_common = counter.most_common(3)
        print(f" - Unique: {len(counter)}")
        print(f" - Top 3 Most Common: {most_common}")

end = time.time()
print(f"\n⏱️ Time taken: {end - start:.2f} seconds")
# Out:
# 📊 Column: account_name
#  - Count: 5159
#  - Unique: 126
#  - Top 3 Most Common: [('Donald J. Trump', 4398), ('Team Trump', 284), ('Real America’s Voice', 81)]
#
# 📊 Column: account_handle
#  - Count: 5159
#  - Unique: 125
#  - Top 3 Most Common: [('realDonaldTrump', 4398), ('TeamTrump', 284), ('realamericasvoice', 81)]
#
# 📊 Column: verified_badge
#  - Count: 5159
#  - Unique: 2
#  - Top 3 Most Common: [('TRUE', 4975), ('FALSE', 184)]
#
# 📊 Column: post_date
#  - Count: 5159
#  - Unique: 4099
#  - Top 3 Most Common: [('2024-09-21 18:22:00', 6), ('2024-09-15 01:36:00', 6), ('2024-08-27 18:20:00', 6)]
#
# 📊 Column: profile_link
#  - Count: 5158
#  - Unique: 124
#  - Top 3 Most Common: [('https://truthsocial.com/@realDonaldTrump', 4398), ('https://truthsocial.com/@TeamTrump', 284), ('https://truthsocial.com/@realamericasvoice', 81)]
#
# 📊 Column: avatar_url
#  - Count: 5159
#  - Unique: 127
#  - Top 3 Most Common: [('https://static-assets-1.truthsocial.com/tmtg:prime-ts-assets/accounts/avatars/107/780/257/626/128/497/original/454286ac07a6f6e6.jpeg', 4398), ('https://static-assets-1.truthsocial.com/tmtg:prime-ts-assets/accounts/avatars/107/821/307/789/811/412/original/5c04cf25966e79e4.jpeg', 284), ('https://static-assets-1.truthsocial.com/tmtg:prime-ts-assets/accounts/avatars/107/837/389/161/471/093/original/199f60906b82ef4a.png', 70)]
#
# 📊 Column: post_url
#  - Count: 4398
#  - Unique: 4131
#  - Top 3 Most Common: [('https://truthsocial.com/@realDonaldTrump/posts/113433196918488481', 2), ('https://truthsocial.com/@realDonaldTrump/posts/113432910293976514', 2), ('https://truthsocial.com/@realDonaldTrump/posts/113427384009130909', 2)]
#
# 📊 Column: status_text
#  - Count: 4240
#  - Unique: 3717
#  - Top 3 Most Common: [('https://www.DonaldJTrump.com', 159), ('MAKE AMERICA GREAT AGAIN!', 21), ('https://swampthevoteusa.com/', 9)]
#
# 📊 Column: replies
#  - Count: 5159
#  - Mean: 304.64
#  - Min: 26.0
#  - Max: 999.0
#  - Std Dev: 244.75
#
# 📊 Column: shares
#  - Count: 5159
#  - Unique: 808
#  - Top 3 Most Common: [('2,36k', 24), ('3,19k', 23), ('2,47k', 21)]
#
# 📊 Column: likes
#  - Count: 5159
#  - Unique: 880
#  - Top 3 Most Common: [('10,4k', 54), ('11,1k', 51), ('12,6k', 49)]
#
# 📊 Column: image_urls/0
#  - Count: 1292
#  - Unique: 1215
#  - Top 3 Most Common: [('https://static-assets-1.truthsocial.com/tmtg:prime-ts-assets/media_attachments/files/113/161/845/761/911/612/original/28fda9d9554bfe0a.jpg', 4), ('https://static-assets-1.truthsocial.com/tmtg:prime-ts-assets/media_attachments/files/113/014/541/881/946/711/original/eee0edb413965f3c.jpg', 3), ('https://static-assets-1.truthsocial.com/tmtg:prime-ts-assets/media_attachments/files/113/156/097/294/715/255/original/840ad56bcef5598b.jpg', 3)]
#
# 📊 Column: video_urls/0/url
#  - Count: 994
#  - Unique: 897
#  - Top 3 Most Common: [('https://1a-1791.com/video/s8/2/D/n/N/5/DnN5s.caa.mp4?b=1&u=ummtf', 3), ('https://1a-1791.com/video/s8/2/r/U/G/4/rUG4s.caa.mp4?b=1&u=ummtf', 3), ('https://1a-1791.com/video/s8/2/g/N/_/p/gN_pu.caa.mp4?b=1&u=ummtf', 2)]
#
# 📊 Column: video_urls/0/quality
#  - Count: 994
#  - Unique: 3
#  - Top 3 Most Common: [('480p', 992), ('1080p', 1), ('720p', 1)]
#
# 📊 Column: video_urls/1/url
#  - Count: 750
#  - Unique: 678
#  - Top 3 Most Common: [('https://1a-1791.com/video/s8/2/r/U/G/4/rUG4s.gaa.mp4?b=1&u=ummtf', 3), ('https://1a-1791.com/video/s8/2/g/N/_/p/gN_pu.gaa.mp4?b=1&u=ummtf', 2), ('https://1a-1791.com/video/s8/2/F/-/W/m/F-Wmu.gaa.mp4?b=1&u=ummtf', 2)]
#
# 📊 Column: video_urls/1/quality
#  - Count: 750
#  - Unique: 3
#  - Top 3 Most Common: [('720p', 742), ('240p', 6), ('1080p', 2)]
#
# 📊 Column: video_urls/2/url
#  - Count: 218
#  - Unique: 194
#  - Top 3 Most Common: [('https://1a-1791.com/video/s8/2/g/N/_/p/gN_pu.haa.mp4?b=1&u=ummtf', 2), ('https://1a-1791.com/video/s8/2/c/h/b/l/chblu.haa.mp4?b=1&u=ummtf', 2), ('https://1a-1791.com/video/s8/2/e/e/j/_/eej_t.haa.mp4?b=1&u=ummtf', 2)]
#
# 📊 Column: video_urls/2/quality
#  - Count: 218
#  - Unique: 2
#  - Top 3 Most Common: [('1080p', 212), ('240p', 6)]
#
# 📊 Column: image_urls/1
#  - Count: 84
#  - Unique: 74
#  - Top 3 Most Common: [('https://static-assets-1.truthsocial.com/tmtg:prime-ts-assets/media_attachments/files/113/161/845/880/543/821/original/1e698250286bd43c.jpg', 4), ('https://static-assets-1.truthsocial.com/tmtg:prime-ts-assets/media_attachments/files/113/156/097/393/205/168/original/bc546b447bf1101f.jpg', 3), ('https://static-assets-1.truthsocial.com/tmtg:prime-ts-assets/media_attachments/files/112/759/679/330/944/969/original/0e2b9c4ebe82a8e9.jpg', 3)]
#
# 📊 Column: image_urls/2
#  - Count: 61
#  - Unique: 51
#  - Top 3 Most Common: [('https://static-assets-1.truthsocial.com/tmtg:prime-ts-assets/media_attachments/files/113/161/845/985/879/507/original/d70e09cad9e71e7e.jpg', 4), ('https://static-assets-1.truthsocial.com/tmtg:prime-ts-assets/media_attachments/files/113/156/097/502/670/814/original/0f6567bc81eb6732.jpg', 3), ('https://static-assets-1.truthsocial.com/tmtg:prime-ts-assets/media_attachments/files/112/759/679/423/686/738/original/7ba432121ccc95d4.jpg', 3)]
#
# 📊 Column: image_urls/3
#  - Count: 56
#  - Unique: 46
#  - Top 3 Most Common: [('https://static-assets-1.truthsocial.com/tmtg:prime-ts-assets/media_attachments/files/113/161/846/113/422/265/original/36ecb6bbbae1025a.jpg', 4), ('https://static-assets-1.truthsocial.com/tmtg:prime-ts-assets/media_attachments/files/113/156/097/611/494/383/original/564649fc8b6b1d25.jpg', 3), ('https://static-assets-1.truthsocial.com/tmtg:prime-ts-assets/media_attachments/files/112/759/679/493/435/069/original/7b572efe9fec4021.jpg', 3)]
#
# 📊 Column: video_urls/3/url
#  - Count: 29
#  - Unique: 25
#  - Top 3 Most Common: [('https://1a-1791.com/video/s8/2/c/h/b/l/chblu.iaa.mp4?b=1&u=ummtf', 2), ('https://1a-1791.com/video/s8/2/e/e/j/_/eej_t.iaa.mp4?b=1&u=ummtf', 2), ('https://1a-1791.com/video/s8/2/v/y/F/P/vyFPt.iaa.mp4?b=1&u=ummtf', 2)]
#
# 📊 Column: video_urls/3/quality
#  - Count: 29
#  - Unique: 2
#  - Top 3 Most Common: [('1440p', 28), ('240p', 1)]
#
# 📊 Column: video_urls/4/url
#  - Count: 21
#  - Unique: 19
#  - Top 3 Most Common: [('https://1a-1791.com/video/s8/2/c/h/b/l/chblu.jaa.mp4?b=1&u=ummtf', 2), ('https://1a-1791.com/video/s8/2/e/e/j/_/eej_t.jaa.mp4?b=1&u=ummtf', 2), ('https://1a-1791.com/video/s8/2/1/r/Z/g/1rZgu.jaa.mp4?b=1&u=ummtf', 1)]
#
# 📊 Column: video_urls/4/quality
#  - Count: 21
#  - Unique: 1
#  - Top 3 Most Common: [('2160p', 21)]
#
# ⏱️ Time taken: 0.09 seconds
